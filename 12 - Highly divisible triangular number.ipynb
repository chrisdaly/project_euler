# %% [markdown]
# ## Description

# %% [markdown]
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
# ```
#  1: 1
#  3: 1,3
#  6: 1,2,3,6
# 10: 1,2,5,10
# 15: 1,3,5,15
# 21: 1,3,7,21
# 28: 1,2,4,7,14,28
# ```
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %% [markdown]
# ## Solution

# %%
from functools import reduce
from utils import timer

# %%
def find_factors(number: int) -> list:
    factors = [1, number]
    for i in range(2, number, 1):
        if (number % i) == 0:
            factors.append(i)
    
    return factors

# %%
@timer
def find_triangle_number_with_n_primes(n: int) -> int:
    i = 1
    num = 0
    triangle_numbers = []
    while True:
        num += i
        i += 1
        triangle_numbers.append(num)
        factors = find_factors(num)
        l = len(factors)
        if l % 5 == 0:
            print(l, num, i)
        if l > n:
            break
            
    return num

# %%
answer = find_triangle_number_with_n_primes(500)
answer
# Out:
# 10 496 32
# 20 528 33
# 40 3240 81
# 10 3321 82
# 40 4560 96
# 20 4656 97
# 40 12720 160
# 40 12880 161
# 20 13041 162
# 10 13203 163
# 20 24976 224
# 90 25200 225
# 60 41328 288
# 45 41616 289
# 40 52326 324
# 60 52650 325
# 80 61776 352
# 20 62128 353
# 40 81810 405
# 40 82215 406
# 40 86320 416
# 40 86736 417
# 40 114960 480
# 80 115440 481
# 40 147696 544
# 40 148240 545
# Finished 'find_triangle_number_with_n_primes' in 1.6625 secs
# 157080
