# %% [markdown]
# # Description

# %% [markdown]
# Take the number 192 and multiply it by each of 1, 2, and 3:
#
# 192 × 1 = 192
# 192 × 2 = 384
# 192 × 3 = 576
# By concatenating each product we get the 1 to 9 pandigital, 192384576. We will call 192384576 the concatenated product of 192 and (1,2,3)
#
# The same can be achieved by starting with 9 and multiplying by 1, 2, 3, 4, and 5, giving the pandigital, 918273645, which is the concatenated product of 9 and (1,2,3,4,5).
#
# What is the largest 1 to 9 pandigital 9-digit number that can be formed as the concatenated product of an integer with (1,2, ... , n) where n > 1?

# %%
multipliers = list(range(1, 10))
multipliers
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
number_is_pan

# %%
concatenated_products = []
for i in range(1, 1000):
    products = []
    for j in multipliers:
        product = i * j
        if product % 10 ** 9 != product:
            break
        products.append(product)
    concatenated_product = "".join([str(x) for x in products])
    concatenated_products.append(concatenated_product)

# %%
def is_pandigital(joined: list) -> bool:
    if len(set(joined)) != 9:
        return False

    left_out_numbers = set(range(1, 9)) - set(joined)
    if len(left_out_numbers) == 0:
        return True
    else:
        return False

# %%
product = 
product % 10 ** 9 != product
# Out:
# True

# %%
concatenated_products
# Out:
# ['123456789',
#  '24681012141618',
#  '369121518212427',
#  '4812162024283236',
#  '51015202530354045',
#  '61218243036424854',
#  '71421283542495663',
#  '81624324048566472',
#  '91827364554637281',
#  '102030405060708090',
#  '112233445566778899',
#  '1224364860728496108',
#  '13263952657891104117',
#  '14284256708498112126',
#  '153045607590105120135',
#  '163248648096112128144',
#  '1734516885102119136153',
#  '1836547290108126144162',
#  '1938577695114133152171',
#  '20406080100120140160180',
#  '21426384105126147168189',
#  '22446688110132154176198',
#  '23466992115138161184207',
#  '24487296120144168192216',
#  '255075100125150175200225',
#  '265278104130156182208234',
#  '275481108135162189216243',
#  '285684112140168196224252',
#  '295887116145174203232261',
#  '306090120150180210240270',
#  '316293124155186217248279',
#  '326496128160192224256288',
#  '336699132165198231264297',
#  '3468102136170204238272306',
#  '3570105140175210245280315',
#  '3672108144180216252288324',
# ...
